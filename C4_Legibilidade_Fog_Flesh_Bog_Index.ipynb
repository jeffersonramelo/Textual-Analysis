# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffersonramelo/Textual-Analysis/blob/main/C4_Legibilidade_Fog_Flesh_Bog_Index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# dados utilizados nesse script:
# http://www.lrec-conf.org/proceedings/lrec2022/workshops/FNP/pdf/2022.fnp-1.1.pdf
# https://github.com/sohomghosh/FinRAD_Financial_Readability_Assessment_Dataset
#
# Trabalho apresentado no: Proceedings of the 4th Financial Narrative Processing Workshop @ LREC 2022, pages 1–9
# Marseille, France, 24 June 2022
#
#
# Primary Columns:
# "terms": This is the financial term
# "definitions": This is the definition corresponding to the financial term
# "source": This represents the source from which the term and the definition has been obtained.
# "assigned_readability": This is the manually assigned readability. 0 means not readable, 1 means readable.
#
# Other Columns:
# "flesch_reading_ease", "flesch_kincaid_grade", "smog_index", "coleman_liau_index", "automated_readability_index", "dale_chall_readability_score", "linsear_write_formula", "gunning_fog"
# These are readability scores extracted using the textstat library

# %%
import pandas as pd

df = pd.read_csv('/content/C41_ dataset legibilidade rotulados.csv')

# %%
# Obtenha as variáveis e seus tipos
variaveis = df.columns.tolist()
tipos = df.dtypes.tolist()

# Imprima as variáveis e seus tipos
for var, tipo in zip(variaveis, tipos):
    print(f'{var}: {tipo}')
# Out:
# terms: object
# definitions: object
# source: object
# assigned_readability: int64
# flesch_reading_ease: float64
# flesch_kincaid_grade: float64
# smog_index: float64
# coleman_liau_index: float64
# automated_readability_index: float64
# dale_chall_readability_score: float64
# linsear_write_formula: float64
# gunning_fog: float64

# %%
df
# Out:
#                                           terms  \
# 0                     Low/No Documentation Loan
# 1     Combined Loan-To-Value Ratio (CLTV Ratio)
# 2                          Nonforfeiture Clause
# 3                        Discretionary spending
# 4                                DEBT TO ASSETS
# ...                                         ...
# 1495                        Sole Proprietorship
# 1496         UCLA Anderson School of Management
# 1497                               Unemployment
# 1498                          Pro Forma Invoice
# 1499                          full-payout lease
#
#                                             definitions        source  \
# 0     A low/no documentation loan allows a potential...  investopedia
# 1     The combined loan-to-value (CLTV) ratio is the...  investopedia
# 2     A nonforfeiture (sometimes hyphenated) clause ...  investopedia
# 3     Government spending authorized by Congress on ...    9_12_louis
# 4     A measure of a company’s FINANCIAL LEVERAGE, o...      palgrave
# ...                                                 ...           ...
# 1495  A sole proprietorship also referred to as a so...  investopedia
# 1496  UCLA Anderson School of Management is the grad...  investopedia
# 1497  @1@ In economic terms,  involuntary unemployme...           sam
# 1498  A pro forma invoice is a preliminary bill of s...  investopedia
# 1499                                   financial lease.          prin
#
#       assigned_readability  flesch_reading_ease  flesch_kincaid_grade  \
# 0                        1                22.75                  15.8
# 1                        1                45.77                  17.3
# 2                        1                29.18                  15.4
# 3                        1                28.50                  11.5
# 4                        0                45.46                  11.2
# ...                    ...                  ...                   ...
# 1495                     1                37.98                  16.2
# 1496                     1                41.70                  12.7
# 1497                     1                15.65                  18.5
# 1498                     1                58.62                  10.3
# 1499                     0                35.61                   8.8
#
#       smog_index  coleman_liau_index  automated_readability_index  \
# 0            0.0               16.42                         17.8
# 1            0.0                9.01                         21.0
# 2           17.1               14.10                         16.9
# 3            0.0               15.11                         11.3
# 4           13.0               10.67                         11.1
# ...          ...                 ...                          ...
# 1495         0.0               11.79                         18.5
# 1496         0.0               12.30                         13.8
# 1497         0.0               10.28                         16.6
# 1498         0.0               11.60                         12.9
# 1499         0.0               10.00                         14.9
#
#       dale_chall_readability_score  linsear_write_formula  gunning_fog
# 0                            11.99              18.000000        20.50
# 1                            10.23              12.500000        18.70
# 2                             9.93              18.500000        15.33
# 3                            12.86               6.500000        12.49
# 4                             9.96              11.666667        10.00
# ...                            ...                    ...          ...
# 1495                          9.10              20.500000        16.84
# 1496                          9.94              16.000000        16.97
# 1497                         11.70              20.500000        16.67
# 1498                         10.69              13.000000        12.21
# 1499                         19.53               1.000000        20.80
#
# [1500 rows x 12 columns]

# %%
#vizualiar 1175 obs
print(df.loc[:, 'definitions'].iloc[0])
# Out:
# A low/no documentation loan allows a potential borrower to apply for a mortgage while providing little or no information regarding their employment, income, or assets. Regulation of these loans has evolved significantly since 2008, but they remain an option for some borrowers in nontraditional financial situations.

# %%
import re

# Função para remover números de uma string
def remover_numeros(texto):
    return re.sub(r'\d+', '', texto)

# Aplicar preprocessamento
df['definitions'] = df['definitions'].apply(remover_numeros)

# Visualizar:
print(df.loc[:, 'definitions'].iloc[2])
# Out:
# A nonforfeiture (sometimes hyphenated) clause is an insurance policy clause stipulating that an insured party can receive full or partial benefits or a partial refund of premiums after a lapse due to non-payment. Standard life insurance and long-term care insurance may have nonforfeiture clauses. The clause may involve returning some portion of the total premiums paid, the cash surrender value of the policy, or a reduced benefit based upon premiums paid before the policy lapsed.

# %%
# !pip install textstat
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting textstat
#   Downloading textstat-0.7.3-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.1/105.1 kB 3.8 MB/s eta 0:00:00
# Collecting pyphen (from textstat)
#   Downloading pyphen-0.14.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 34.2 MB/s eta 0:00:00
# Installing collected packages: pyphen, textstat
# Successfully installed pyphen-0.14.0 textstat-0.7.3

# %% [markdown]
# se necessário:

# %%
import re
from textstat import textstat

# Função para remover palavras específicas de uma string
def remover_palavras(texto):
    palavras_remover = ['MATERIAL FACT', 'NIRE', 'CNPJ']
    padrao = r'\b(?:{})\b'.format('|'.join(map(re.escape, palavras_remover)))
    return re.sub(padrao, '', texto)

# Aplicar preprocessamento
df['definitions'] = df['definitions'].apply(remover_palavras)

# Visualizar o resultado do primeiro texto
print(df.loc[:, 'definitions'].iloc[0])

# %% [markdown]
# se necessário:

# %%
import re

# Função para remover padrões específicos de uma string
def remover_padroes(texto):
    padroes_remover = ['S\.A\.', 'nº', '/ME', '/']
    for padrao in padroes_remover:
        texto = re.sub(padrao, '', texto)
    return texto

# Aplicar remoção de padrões
df['definitions'] = df['definitions'].apply(remover_padroes)


# Visualizar o resultado do primeiro texto
print(df.loc[:, 'definitions'].iloc[0])

# %%
import re
from textstat import textstat

# Aplicar preprocessamento e calcular o Fog Index no DataFrame
df['fog_index'] = df['definitions'].apply(lambda x: textstat.gunning_fog(x))

# Visualizar o resultado
print(df[['definitions', 'fog_index']])
# Out:
#                                             definitions  fog_index
# 0     A low/no documentation loan allows a potential...      20.56
# 1     The combined loan-to-value (CLTV) ratio is the...      10.30
# 2     A nonforfeiture (sometimes hyphenated) clause ...      15.33
# 3     Government spending authorized by Congress on ...      12.49
# 4     A measure of a company’s FINANCIAL LEVERAGE, o...       8.28
# ...                                                 ...        ...
# 1495  A sole proprietorship also referred to as a so...      16.84
# 1496  UCLA Anderson School of Management is the grad...      16.98
# 1497  @@ In economic terms,  involuntary unemploymen...      12.55
# 1498  A pro forma invoice is a preliminary bill of s...      12.21
# 1499                                   financial lease.      20.80
#
# [1500 rows x 2 columns]

# %%
desc_estatisticas = df['fog_index'].describe()
print(desc_estatisticas)
# Out:
# count    1500.000000
# mean       13.935347
# std         4.900684
# min         0.400000
# 25%        11.400000
# 50%        13.940000
# 75%        16.520000
# max        40.800000
# Name: fog_index, dtype: float64

# %%
import re
from textstat import textstat
import numpy as np

# Function to calculate the Flesch Index
def calculate_flesch(text):
    sentences = textstat.sentence_count(text)
    words = textstat.lexicon_count(text, removepunct=True)
    syllables = textstat.syllable_count(text)

    if words == 0:
        return np.nan

    average_words_per_sentence = words / sentences
    average_syllables_per_word = syllables / words

    flesch_index = 206.835 - (1.015 * average_words_per_sentence) - (84.6 * average_syllables_per_word)
    return flesch_index

# Apply preprocessing and calculate the Flesch Index in the 'df' DataFrame
df['flesch_index'] = df['definitions'].apply(calculate_flesch)

# View the result
print(df[['definitions', 'flesch_index']])
# Out:
#                                             definitions  flesch_index
# 0     A low/no documentation loan allows a potential...     18.557500
# 1     The combined loan-to-value (CLTV) ratio is the...     64.662857
# 2     A nonforfeiture (sometimes hyphenated) clause ...     32.564000
# 3     Government spending authorized by Congress on ...     28.500000
# 4     A measure of a company’s FINANCIAL LEVERAGE, o...     53.724615
# ...                                                 ...           ...
# 1495  A sole proprietorship also referred to as a so...     34.903636
# 1496  UCLA Anderson School of Management is the grad...     41.588476
# 1497  @@ In economic terms,  involuntary unemploymen...     53.018563
# 1498  A pro forma invoice is a preliminary bill of s...     52.577143
# 1499                                   financial lease.     35.605000
#
# [1500 rows x 2 columns]

# %%
# Calculate the correlation between 'fog_index' and 'flesch_index'
correlation = df['fog_index'].corr(df['flesch_index'])

# Print the correlation value
print("Correlation between fog_index and flesch_index:", correlation)
# Out:
# Correlation between fog_index and flesch_index: -0.751258119624869

# %%
# !pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2022.10.31)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.65.0)

# %% [markdown]
# Exemplo de uso do Bog Index

# %%
import pandas as pd

def calculate_bog_index(df):
    # Define the lists of overused words, weak verbs, jargon, and passive voice indicators
    overused_words = ['utilize', 'implement', 'execute', 'generate', 'obtain']
    weak_verbs = ['be', 'have', 'do', 'go', 'give']
    jargon_words = ['ROI', 'EBITDA', 'hedge', 'derivatives', 'IPO', 'compliance', 'capital market', 'due diligence', 'blue chip', 'sovereign debt']
    passive_voice_indicators = ['be', 'am', 'is', 'are', 'was', 'were', 'been', 'being']

    # Initialize the Bog Index column
    df['bog_index'] = 0.0

    # Iterate over each row and calculate the Bog Index for the corresponding text
    for index, row in df.iterrows():
        text = row['definitions']
        sentences = text.split('.')
        sentence_count = len(sentences)
        passive_count = 0
        weak_verb_count = 0
        overused_word_count = 0
        jargon_word_count = 0

        for sentence in sentences:
            words = sentence.split()

            if any(word in passive_voice_indicators for word in words) and 'by' in words:
                passive_count += 1

            if any(word in weak_verbs for word in words):
                weak_verb_count += 1

            if any(word in overused_words for word in words):
                overused_word_count += 1

            if any(word in jargon_words for word in words):
                jargon_word_count += 1

        bog_index = (passive_count + weak_verb_count + overused_word_count + jargon_word_count) / sentence_count

        # Update the Bog Index value in the DataFrame
        df.at[index, 'bog_index'] = bog_index

    return df

# Apply Bog Index calculation to the 'definitions' column in the existing DataFrame
df = calculate_bog_index(df)

# View the result
print(df[['definitions', 'bog_index']])
# Out:
#                                             definitions  bog_index
# 0     A low/no documentation loan allows a potential...       0.00
# 1     The combined loan-to-value (CLTV) ratio is the...       0.00
# 2     A nonforfeiture (sometimes hyphenated) clause ...       0.25
# 3     Government spending authorized by Congress on ...       0.00
# 4     A measure of a company’s FINANCIAL LEVERAGE, o...       0.00
# ...                                                 ...        ...
# 1495  A sole proprietorship also referred to as a so...       0.00
# 1496  UCLA Anderson School of Management is the grad...       0.00
# 1497  @@ In economic terms,  involuntary unemploymen...       0.00
# 1498  A pro forma invoice is a preliminary bill of s...       0.00
# 1499                                   financial lease.       0.00
#
# [1500 rows x 2 columns]

# %%
desc_estatisticas = df['bog_index'].describe()
print(desc_estatisticas)
# Out:
# count    1500.000000
# mean        0.147864
# std         0.221846
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.285714
# max         1.500000
# Name: bog_index, dtype: float64

# %%
df
# Out:
#                                           terms  \
# 0                     Low/No Documentation Loan
# 1     Combined Loan-To-Value Ratio (CLTV Ratio)
# 2                          Nonforfeiture Clause
# 3                        Discretionary spending
# 4                                DEBT TO ASSETS
# ...                                         ...
# 1495                        Sole Proprietorship
# 1496         UCLA Anderson School of Management
# 1497                               Unemployment
# 1498                          Pro Forma Invoice
# 1499                          full-payout lease
#
#                                             definitions        source  \
# 0     A low/no documentation loan allows a potential...  investopedia
# 1     The combined loan-to-value (CLTV) ratio is the...  investopedia
# 2     A nonforfeiture (sometimes hyphenated) clause ...  investopedia
# 3     Government spending authorized by Congress on ...    9_12_louis
# 4     A measure of a company’s FINANCIAL LEVERAGE, o...      palgrave
# ...                                                 ...           ...
# 1495  A sole proprietorship also referred to as a so...  investopedia
# 1496  UCLA Anderson School of Management is the grad...  investopedia
# 1497  @@ In economic terms,  involuntary unemploymen...           sam
# 1498  A pro forma invoice is a preliminary bill of s...  investopedia
# 1499                                   financial lease.          prin
#
#       assigned_readability  flesch_reading_ease  flesch_kincaid_grade  \
# 0                        1                22.75                  15.8
# 1                        1                45.77                  17.3
# 2                        1                29.18                  15.4
# 3                        1                28.50                  11.5
# 4                        0                45.46                  11.2
# ...                    ...                  ...                   ...
# 1495                     1                37.98                  16.2
# 1496                     1                41.70                  12.7
# 1497                     1                15.65                  18.5
# 1498                     1                58.62                  10.3
# 1499                     0                35.61                   8.8
#
#       smog_index  coleman_liau_index  automated_readability_index  \
# 0            0.0               16.42                         17.8
# 1            0.0                9.01                         21.0
# 2           17.1               14.10                         16.9
# 3            0.0               15.11                         11.3
# 4           13.0               10.67                         11.1
# ...          ...                 ...                          ...
# 1495         0.0               11.79                         18.5
# 1496         0.0               12.30                         13.8
# 1497         0.0               10.28                         16.6
# 1498         0.0               11.60                         12.9
# 1499         0.0               10.00                         14.9
#
#       dale_chall_readability_score  linsear_write_formula  gunning_fog  \
# 0                            11.99              18.000000        20.50
# 1                            10.23              12.500000        18.70
# 2                             9.93              18.500000        15.33
# 3                            12.86               6.500000        12.49
# 4                             9.96              11.666667        10.00
# ...                            ...                    ...          ...
# 1495                          9.10              20.500000        16.84
# 1496                          9.94              16.000000        16.97
# 1497                         11.70              20.500000        16.67
# 1498                         10.69              13.000000        12.21
# 1499                         19.53               1.000000        20.80
#
#       fog_index  flesch_index  bog_index
# 0         20.56     18.557500       0.00
# 1         10.30     64.662857       0.00
# 2         15.33     32.564000       0.25
# 3         12.49     28.500000       0.00
# 4          8.28     53.724615       0.00
# ...         ...           ...        ...
# 1495      16.84     34.903636       0.00
# 1496      16.98     41.588476       0.00
# 1497      12.55     53.018563       0.00
# 1498      12.21     52.577143       0.00
# 1499      20.80     35.605000       0.00
#
# [1500 rows x 15 columns]
